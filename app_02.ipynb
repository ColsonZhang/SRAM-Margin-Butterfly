# %%
import sys
import numpy as np
sys.path.append("./src")
from draw import *
from margin import *
from read import *
from butterfly import *
import matplotlib.pyplot as plt

# %%
filename_3 = "./data/data1/06_read_q_vbl_0.csv"
filename_4 = "./data/data1/06_read_qb_vbl_0.csv"

# %%
# zeros = [0,0,0,0, 0, 0.2, 0, 0]
the_zeros = 0
the_start =-0.9
the_end = 0.9

margins,curve_1,curve_2,squares = multi_margin_find(filename_3, filename_4, mode="read", 
                                                zeros=the_zeros,start=the_start,end=the_end, line_span=0.9,
                                                auto_zero=True, auto_start=True)

# %%
number_curves = 21
the_row = 3
the_column = 7
the_titles = np.linspace(0.4, 0.9, number_curves)

margin_draw(curve_1,curve_2,squares,number=number_curves,titles=the_titles, rows=the_row, columns=the_column)

# %%
the_plot_y = margins[1:13]
the_plot_x = the_titles[1:13]

# %%
plt.plot(the_plot_x, the_plot_y)
plt.show()

# %%
filename_3 = "./data/07_read_q_vbl_1.csv"
filename_4 = "./data/07_read_qb_vbl_1.csv"

# %%
# zeros = [0,0,0,0, -0.2, -0.1, 0, 0]
# start = [-0.9,-0.9,-0.9,-0.9, -0.6, -0.7, -0.8, -0.8]
the_zeros = 0
the_start = -0.9
the_end = 0.9
margins,curve_1,curve_2,squares = multi_margin_find(filename_3, filename_4, mode="read", 
                                                    zeros=the_zeros,start=the_start,end=the_end, line_span=0.9,
                                                    auto_zero=True, auto_start=True)

# %%
number_curves = 21
the_row = 3
the_column = 7
the_titles = np.linspace(0.4, 0.9, number_curves)

margin_draw(curve_1,curve_2,squares,number=number_curves,titles=the_titles, rows=the_row, columns=the_column)

# %%
the_plot_y = margins[3:]
the_plot_x = the_titles[3:]

# %%
plt.plot(the_plot_x, the_plot_y)
plt.show()

# %%
filename_3 = "./data/08_write_qb.csv"
filename_4 = "./data/08_write_q.csv"

# %%
the_zeros = 0
the_start = -0.9
the_end = 0.9
margins,curve_1,curve_2,squares = multi_margin_find(filename_3, filename_4, mode="write", 
                                                    zeros=the_zeros,start=the_start,end=the_end, line_span=0.9,
                                                    auto_zero=True, auto_start=True,
                                                    search_ratio=0.7)

# %%
number_curves = 21
the_row = 3
the_column = 7
the_titles = np.linspace(0.4, 0.9, number_curves)

margin_draw(curve_1,curve_2,squares,number=number_curves,titles=the_titles, rows=the_row, columns=the_column)

# %%
the_plot_y = margins
the_plot_x = the_titles

# %%
plt.plot(the_plot_x, the_plot_y)
plt.show()
